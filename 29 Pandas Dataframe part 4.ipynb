# %%
import pandas as pd
import numpy as np

# %%
data ={'name': ['Somu', 'Kiku', 'Amol', 'Lini'],
'physics': [68, 74, 77, 78],
'chemistry': [84, 56, 73, 69],
'algebra': [78, 88, 82, 87]}

# %%
data
# Out:
# {'name': ['Somu', 'Kiku', 'Amol', 'Lini'],
#  'physics': [68, 74, 77, 78],
#  'chemistry': [84, 56, 73, 69],
#  'algebra': [78, 88, 82, 87]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    name  physics  chemistry  algebra
# 0  Somu       68         84       78
# 1  Kiku       74         56       88
# 2  Amol       77         73       82
# 3  Lini       78         69       87

# %% [markdown]
# ### To add row in Existing Dataframe

# %%
row={"name":["Ananda"],"physics":[90],"chemistry":[85],"algebra":[80]}
df2=pd.DataFrame(row)
df2
# Out:
#      name  physics  chemistry  algebra
# 0  Ananda       90         85       80

# %%
pd.concat([df,df2])
# Out:
#      name  physics  chemistry  algebra
# 0    Somu       68         84       78
# 1    Kiku       74         56       88
# 2    Amol       77         73       82
# 3    Lini       78         69       87
# 0  Ananda       90         85       80

# %%
df
# Out:
#    name  physics  chemistry  algebra
# 0  Somu       68         84       78
# 1  Kiku       74         56       88
# 2  Amol       77         73       82
# 3  Lini       78         69       87

# %%
data = pd.DataFrame({'Brand' : ['Maruti','Maruti', 'Hyundai', 'Tata',
                                'Mahindra', 'Maruti', 'Hyundai',
                                'Renault', 'Tata', 'Maruti'],
                     'Year' : [2012,2012, 2014, 2011, 2015, 2012, 
                               2016, 2014, 2018, 2019],
                     'Kms Driven' : [50000,50000, 30000, 60000, 
                                     25000, 10000, 46000, 
                                     31000, 15000, 12000],
                     'City' : ['Gurgaon','Gurgaon', 'Delhi', 'Mumbai', 
                               'Delhi', 'Mumbai', 'Delhi', 
                               'Mumbai','Chennai',  'Ghaziabad'],
                     'Mileage' :  [28,28, 27, 25, 26, 28, 
                                   29, 24, 21, 24]})

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %% [markdown]
# # APPLY

# %%
def my_mileage(row):
    if row>25:
        return "HIGH"
    else:
        return "LOW"

# %%
data["Mileage_Type"]=data["Mileage"].apply(my_mileage)

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage Mileage_Type
# 0    Maruti  2012       50000    Gurgaon       28         HIGH
# 1    Maruti  2012       50000    Gurgaon       28         HIGH
# 2   Hyundai  2014       30000      Delhi       27         HIGH
# 3      Tata  2011       60000     Mumbai       25          LOW
# 4  Mahindra  2015       25000      Delhi       26         HIGH
# 5    Maruti  2012       10000     Mumbai       28         HIGH
# 6   Hyundai  2016       46000      Delhi       29         HIGH
# 7   Renault  2014       31000     Mumbai       24          LOW
# 8      Tata  2018       15000    Chennai       21          LOW
# 9    Maruti  2019       12000  Ghaziabad       24          LOW

# %%
data["shahji"]="Hero"

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage Mileage_Type shahji
# 0    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 1    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 2   Hyundai  2014       30000      Delhi       27         HIGH   Hero
# 3      Tata  2011       60000     Mumbai       25          LOW   Hero
# 4  Mahindra  2015       25000      Delhi       26         HIGH   Hero
# 5    Maruti  2012       10000     Mumbai       28         HIGH   Hero
# 6   Hyundai  2016       46000      Delhi       29         HIGH   Hero
# 7   Renault  2014       31000     Mumbai       24          LOW   Hero
# 8      Tata  2018       15000    Chennai       21          LOW   Hero
# 9    Maruti  2019       12000  Ghaziabad       24          LOW   Hero

# %%
def km(r):
    if r >50000:
        return "OLD CAR"
    elif r>30000 and r<49999:
        return "NORMAL CAR"
    else:
        return "NEW CAR"

# %%
data["CAR_TYPE"]=data["Kms Driven"].apply(km)

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage Mileage_Type shahji  \
# 0    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 1    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 2   Hyundai  2014       30000      Delhi       27         HIGH   Hero
# 3      Tata  2011       60000     Mumbai       25          LOW   Hero
# 4  Mahindra  2015       25000      Delhi       26         HIGH   Hero
# 5    Maruti  2012       10000     Mumbai       28         HIGH   Hero
# 6   Hyundai  2016       46000      Delhi       29         HIGH   Hero
# 7   Renault  2014       31000     Mumbai       24          LOW   Hero
# 8      Tata  2018       15000    Chennai       21          LOW   Hero
# 9    Maruti  2019       12000  Ghaziabad       24          LOW   Hero
#
#      CAR_TYPE
# 0     NEW CAR
# 1     NEW CAR
# 2     NEW CAR
# 3     OLD CAR
# 4     NEW CAR
# 5     NEW CAR
# 6  NORMAL CAR
# 7  NORMAL CAR
# 8     NEW CAR
# 9     NEW CAR

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage Mileage_Type shahji  \
# 0    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 1    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 2   Hyundai  2014       30000      Delhi       27         HIGH   Hero
# 3      Tata  2011       60000     Mumbai       25          LOW   Hero
# 4  Mahindra  2015       25000      Delhi       26         HIGH   Hero
# 5    Maruti  2012       10000     Mumbai       28         HIGH   Hero
# 6   Hyundai  2016       46000      Delhi       29         HIGH   Hero
# 7   Renault  2014       31000     Mumbai       24          LOW   Hero
# 8      Tata  2018       15000    Chennai       21          LOW   Hero
# 9    Maruti  2019       12000  Ghaziabad       24          LOW   Hero
#
#      CAR_TYPE
# 0     NEW CAR
# 1     NEW CAR
# 2     NEW CAR
# 3     OLD CAR
# 4     NEW CAR
# 5     NEW CAR
# 6  NORMAL CAR
# 7  NORMAL CAR
# 8     NEW CAR
# 9     NEW CAR

# %%
data["engine type"]="pertol"

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage Mileage_Type shahji  \
# 0    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 1    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 2   Hyundai  2014       30000      Delhi       27         HIGH   Hero
# 3      Tata  2011       60000     Mumbai       25          LOW   Hero
# 4  Mahindra  2015       25000      Delhi       26         HIGH   Hero
# 5    Maruti  2012       10000     Mumbai       28         HIGH   Hero
# 6   Hyundai  2016       46000      Delhi       29         HIGH   Hero
# 7   Renault  2014       31000     Mumbai       24          LOW   Hero
# 8      Tata  2018       15000    Chennai       21          LOW   Hero
# 9    Maruti  2019       12000  Ghaziabad       24          LOW   Hero
#
#      CAR_TYPE engine type
# 0     NEW CAR      pertol
# 1     NEW CAR      pertol
# 2     NEW CAR      pertol
# 3     OLD CAR      pertol
# 4     NEW CAR      pertol
# 5     NEW CAR      pertol
# ...

# %%
data.loc[:,["Brand","Year","engine type","Kms Driven","City","Mileage","Mileage_Type","CAR_TYPE"]]

# re-arrange the coln as per your wish
# Out:
#       Brand  Year engine type  Kms Driven       City  Mileage Mileage_Type  \
# 0    Maruti  2012      pertol       50000    Gurgaon       28         HIGH
# 1    Maruti  2012      pertol       50000    Gurgaon       28         HIGH
# 2   Hyundai  2014      pertol       30000      Delhi       27         HIGH
# 3      Tata  2011      pertol       60000     Mumbai       25          LOW
# 4  Mahindra  2015      pertol       25000      Delhi       26         HIGH
# 5    Maruti  2012      pertol       10000     Mumbai       28         HIGH
# 6   Hyundai  2016      pertol       46000      Delhi       29         HIGH
# 7   Renault  2014      pertol       31000     Mumbai       24          LOW
# 8      Tata  2018      pertol       15000    Chennai       21          LOW
# 9    Maruti  2019      pertol       12000  Ghaziabad       24          LOW
#
#      CAR_TYPE
# 0     NEW CAR
# 1     NEW CAR
# 2     NEW CAR
# 3     OLD CAR
# 4     NEW CAR
# 5     NEW CAR
# 6  NORMAL CAR
# 7  NORMAL CAR
# ...

# %%
data.loc[:,"Brand":"Mileage"]
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
my_dict={1:"A",2:"B"}

# %%
my_dict[3]="C"

# %%
my_dict
# Out:
# {1: 'A', 2: 'B', 3: 'C'}

# %% [markdown]
# # N-LARGEST and N-Smallest

# %%
data.nlargest(1,"Mileage")

# give top largest or highest or topmost value for the col
# Out:
#      Brand  Year  Kms Driven   City  Mileage Mileage_Type shahji    CAR_TYPE  \
# 6  Hyundai  2016       46000  Delhi       29         HIGH   Hero  NORMAL CAR
#
#   engine type
# 6      pertol

# %%
data.nlargest(3,"Mileage")

# give top 3 largest or 3highest or top3 value for the col
# Out:
#      Brand  Year  Kms Driven     City  Mileage Mileage_Type shahji  \
# 6  Hyundai  2016       46000    Delhi       29         HIGH   Hero
# 0   Maruti  2012       50000  Gurgaon       28         HIGH   Hero
# 1   Maruti  2012       50000  Gurgaon       28         HIGH   Hero
#
#      CAR_TYPE engine type
# 6  NORMAL CAR      pertol
# 0     NEW CAR      pertol
# 1     NEW CAR      pertol

# %%
data.nsmallest(1,"Kms Driven")
# Out:
#     Brand  Year  Kms Driven    City  Mileage Mileage_Type shahji CAR_TYPE  \
# 5  Maruti  2012       10000  Mumbai       28         HIGH   Hero  NEW CAR
#
#   engine type
# 5      pertol

# %%
data.nsmallest(3,"Kms Driven")
# Out:
#     Brand  Year  Kms Driven       City  Mileage Mileage_Type shahji CAR_TYPE  \
# 5  Maruti  2012       10000     Mumbai       28         HIGH   Hero  NEW CAR
# 9  Maruti  2019       12000  Ghaziabad       24          LOW   Hero  NEW CAR
# 8    Tata  2018       15000    Chennai       21          LOW   Hero  NEW CAR
#
#   engine type
# 5      pertol
# 9      pertol
# 8      pertol

# %%
data.nsmallest(3,"Kms Driven")[["Brand","Year"]]
# Out:
#     Brand  Year
# 5  Maruti  2012
# 9  Maruti  2019
# 8    Tata  2018

# %%
data.nsmallest(3,"Kms Driven")[["Brand"]]
# Out:
#     Brand
# 5  Maruti
# 9  Maruti
# 8    Tata

# %% [markdown]
# # deleting col from the dataframe

# %%
df1=data.drop("Mileage",axis=1)
df1
# Out:
#       Brand  Year  Kms Driven       City Mileage_Type shahji    CAR_TYPE  \
# 0    Maruti  2012       50000    Gurgaon         HIGH   Hero     NEW CAR
# 1    Maruti  2012       50000    Gurgaon         HIGH   Hero     NEW CAR
# 2   Hyundai  2014       30000      Delhi         HIGH   Hero     NEW CAR
# 3      Tata  2011       60000     Mumbai          LOW   Hero     OLD CAR
# 4  Mahindra  2015       25000      Delhi         HIGH   Hero     NEW CAR
# 5    Maruti  2012       10000     Mumbai         HIGH   Hero     NEW CAR
# 6   Hyundai  2016       46000      Delhi         HIGH   Hero  NORMAL CAR
# 7   Renault  2014       31000     Mumbai          LOW   Hero  NORMAL CAR
# 8      Tata  2018       15000    Chennai          LOW   Hero     NEW CAR
# 9    Maruti  2019       12000  Ghaziabad          LOW   Hero     NEW CAR
#
#   engine type
# 0      pertol
# 1      pertol
# 2      pertol
# 3      pertol
# 4      pertol
# 5      pertol
# 6      pertol
# 7      pertol
# 8      pertol
# ...

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage Mileage_Type shahji  \
# 0    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 1    Maruti  2012       50000    Gurgaon       28         HIGH   Hero
# 2   Hyundai  2014       30000      Delhi       27         HIGH   Hero
# 3      Tata  2011       60000     Mumbai       25          LOW   Hero
# 4  Mahindra  2015       25000      Delhi       26         HIGH   Hero
# 5    Maruti  2012       10000     Mumbai       28         HIGH   Hero
# 6   Hyundai  2016       46000      Delhi       29         HIGH   Hero
# 7   Renault  2014       31000     Mumbai       24          LOW   Hero
# 8      Tata  2018       15000    Chennai       21          LOW   Hero
# 9    Maruti  2019       12000  Ghaziabad       24          LOW   Hero
#
#      CAR_TYPE engine type
# 0     NEW CAR      pertol
# 1     NEW CAR      pertol
# 2     NEW CAR      pertol
# 3     OLD CAR      pertol
# 4     NEW CAR      pertol
# 5     NEW CAR      pertol
# ...

# %%
import pandas as pd
data.drop("Mileage",axis=1,inplace=True)

# %%
# inplace : make changes in orginal df

# %%
data
# Out:
#       Brand  Year  Kms Driven       City Mileage_Type shahji    CAR_TYPE  \
# 0    Maruti  2012       50000    Gurgaon         HIGH   Hero     NEW CAR
# 1    Maruti  2012       50000    Gurgaon         HIGH   Hero     NEW CAR
# 2   Hyundai  2014       30000      Delhi         HIGH   Hero     NEW CAR
# 3      Tata  2011       60000     Mumbai          LOW   Hero     OLD CAR
# 4  Mahindra  2015       25000      Delhi         HIGH   Hero     NEW CAR
# 5    Maruti  2012       10000     Mumbai         HIGH   Hero     NEW CAR
# 6   Hyundai  2016       46000      Delhi         HIGH   Hero  NORMAL CAR
# 7   Renault  2014       31000     Mumbai          LOW   Hero  NORMAL CAR
# 8      Tata  2018       15000    Chennai          LOW   Hero     NEW CAR
# 9    Maruti  2019       12000  Ghaziabad          LOW   Hero     NEW CAR
#
#   engine type
# 0      pertol
# 1      pertol
# 2      pertol
# 3      pertol
# 4      pertol
# 5      pertol
# 6      pertol
# 7      pertol
# 8      pertol
# ...

# %% [markdown]
# axis=1 column -one
#
# axis=0 row -zero

# %%
data.drop("Year",axis=1)
# Out:
#       Brand  Kms Driven       City Mileage_Type shahji    CAR_TYPE engine type
# 0    Maruti       50000    Gurgaon         HIGH   Hero     NEW CAR      pertol
# 1    Maruti       50000    Gurgaon         HIGH   Hero     NEW CAR      pertol
# 2   Hyundai       30000      Delhi         HIGH   Hero     NEW CAR      pertol
# 3      Tata       60000     Mumbai          LOW   Hero     OLD CAR      pertol
# 4  Mahindra       25000      Delhi         HIGH   Hero     NEW CAR      pertol
# 5    Maruti       10000     Mumbai         HIGH   Hero     NEW CAR      pertol
# 6   Hyundai       46000      Delhi         HIGH   Hero  NORMAL CAR      pertol
# 7   Renault       31000     Mumbai          LOW   Hero  NORMAL CAR      pertol
# 8      Tata       15000    Chennai          LOW   Hero     NEW CAR      pertol
# 9    Maruti       12000  Ghaziabad          LOW   Hero     NEW CAR      pertol

# %%
data = pd.DataFrame({'Brand' : ['Maruti','Maruti', 'Hyundai', 'Tata',
                                'Mahindra', 'Maruti', 'Hyundai',
                                'Renault', 'Tata', 'Maruti'],
                     'Year' : [2012,2012, 2014, 2011, 2015, 2012, 
                               2016, 2014, 2018, 2019],
                     'Kms Driven' : [50000,50000, 30000, 60000, 
                                     25000, 10000, 46000, 
                                     31000, 15000, 12000],
                     'City' : ['Gurgaon','Gurgaon', 'Delhi', 'Mumbai', 
                               'Delhi', 'Mumbai', 'Delhi', 
                               'Mumbai','Chennai',  'Ghaziabad'],
                     'Mileage' :  [28,28, 27, 25, 26, 28, 
                                   29, 24, 21, 24]})
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
data.drop(["Year","City"],axis=1)
# Out:
#       Brand  Kms Driven  Mileage
# 0    Maruti       50000       28
# 1    Maruti       50000       28
# 2   Hyundai       30000       27
# 3      Tata       60000       25
# 4  Mahindra       25000       26
# 5    Maruti       10000       28
# 6   Hyundai       46000       29
# 7   Renault       31000       24
# 8      Tata       15000       21
# 9    Maruti       12000       24

# %%
del data["Year"]

# %%
data
# Out:
#       Brand  Kms Driven       City  Mileage
# 0    Maruti       50000    Gurgaon       28
# 1    Maruti       50000    Gurgaon       28
# 2   Hyundai       30000      Delhi       27
# 3      Tata       60000     Mumbai       25
# 4  Mahindra       25000      Delhi       26
# 5    Maruti       10000     Mumbai       28
# 6   Hyundai       46000      Delhi       29
# 7   Renault       31000     Mumbai       24
# 8      Tata       15000    Chennai       21
# 9    Maruti       12000  Ghaziabad       24

# %%
# drop
# del
# pop

# %%
data.pop("Mileage")
# Out:
# 0    28
# 1    28
# 2    27
# 3    25
# 4    26
# 5    28
# 6    29
# 7    24
# 8    21
# 9    24
# Name: Mileage, dtype: int64

# %%
data
# Out:
#       Brand  Kms Driven       City
# 0    Maruti       50000    Gurgaon
# 1    Maruti       50000    Gurgaon
# 2   Hyundai       30000      Delhi
# 3      Tata       60000     Mumbai
# 4  Mahindra       25000      Delhi
# 5    Maruti       10000     Mumbai
# 6   Hyundai       46000      Delhi
# 7   Renault       31000     Mumbai
# 8      Tata       15000    Chennai
# 9    Maruti       12000  Ghaziabad

# %% [markdown]
# ### deleting rows

# %%
data = pd.DataFrame({'Brand' : ['Maruti','Maruti', 'Hyundai', 'Tata',
                                'Mahindra', 'Maruti', 'Hyundai',
                                'Renault', 'Tata', 'Maruti'],
                     'Year' : [2012,2012, 2014, 2011, 2015, 2012, 
                               2016, 2014, 2018, 2019],
                     'Kms Driven' : [50000,50000, 30000, 60000, 
                                     25000, 10000, 46000, 
                                     31000, 15000, 12000],
                     'City' : ['Gurgaon','Gurgaon', 'Delhi', 'Mumbai', 
                               'Delhi', 'Mumbai', 'Delhi', 
                               'Mumbai','Chennai',  'Ghaziabad'],
                     'Mileage' :  [28,28, 27, 25, 26, 28, 
                                   29, 24, 21, 24]})

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
data.drop([0,4,5,9])
# Out:
#      Brand  Year  Kms Driven     City  Mileage
# 1   Maruti  2012       50000  Gurgaon       28
# 2  Hyundai  2014       30000    Delhi       27
# 3     Tata  2011       60000   Mumbai       25
# 6  Hyundai  2016       46000    Delhi       29
# 7  Renault  2014       31000   Mumbai       24
# 8     Tata  2018       15000  Chennai       21

# %%
data.drop(range(4,8))   #range(start,stop,step)   /   l[start:stop:step]
# Out:
#      Brand  Year  Kms Driven       City  Mileage
# 0   Maruti  2012       50000    Gurgaon       28
# 1   Maruti  2012       50000    Gurgaon       28
# 2  Hyundai  2014       30000      Delhi       27
# 3     Tata  2011       60000     Mumbai       25
# 8     Tata  2018       15000    Chennai       21
# 9   Maruti  2019       12000  Ghaziabad       24

# %%
data.drop(data.index[0:4])

# this is position based
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
df = {'name': ['Somu', 'Kiku', 'Amol', 'Lini'],
'physics': [68, 74, 77, 78],
'chemistry': [84, 56, 73, 69],
'algebra': [78, 88, 82, 87]}

df_1=pd.DataFrame(df)

# %%
df_1
# Out:
#    name  physics  chemistry  algebra
# 0  Somu       68         84       78
# 1  Kiku       74         56       88
# 2  Amol       77         73       82
# 3  Lini       78         69       87

# %%
df_1.set_index("name",inplace=True)

#  how to make a col index

# %%
df_1
# Out:
#       physics  chemistry  algebra
# name
# Somu       68         84       78
# Kiku       74         56       88
# Amol       77         73       82
# Lini       78         69       87

# %%
df_1.drop(["Somu","Kiku"])
# Out:
#       physics  chemistry  algebra
# name
# Amol       77         73       82
# Lini       78         69       87

# %%
df_1.drop(df_1.index[0:2])
# Out:
#       physics  chemistry  algebra
# name
# Amol       77         73       82
# Lini       78         69       87

# %% [markdown]
# ## Renaming the col_names

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
data.rename(columns={"Brand":"A","Mileage":"M"})
# Out:
#           A  Year  Kms Driven       City   M
# 0    Maruti  2012       50000    Gurgaon  28
# 1    Maruti  2012       50000    Gurgaon  28
# 2   Hyundai  2014       30000      Delhi  27
# 3      Tata  2011       60000     Mumbai  25
# 4  Mahindra  2015       25000      Delhi  26
# 5    Maruti  2012       10000     Mumbai  28
# 6   Hyundai  2016       46000      Delhi  29
# 7   Renault  2014       31000     Mumbai  24
# 8      Tata  2018       15000    Chennai  21
# 9    Maruti  2019       12000  Ghaziabad  24

# %%
index=list(range(9,-1,-1))
index
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, 0]

# %%
index=list(range(9,-1,-1))
data.reindex(index)

# to change the row index
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 9    Maruti  2019       12000  Ghaziabad       24
# 8      Tata  2018       15000    Chennai       21
# 7   Renault  2014       31000     Mumbai       24
# 6   Hyundai  2016       46000      Delhi       29
# 5    Maruti  2012       10000     Mumbai       28
# 4  Mahindra  2015       25000      Delhi       26
# 3      Tata  2011       60000     Mumbai       25
# 2   Hyundai  2014       30000      Delhi       27
# 1    Maruti  2012       50000    Gurgaon       28
# 0    Maruti  2012       50000    Gurgaon       28

# %% [markdown]
# # Handling missing data

# %%
df_weather=pd.read_csv(r"C:\Users\ipcs nagpur\Downloads\weather_data1.csv")

# %%
df_weather
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df_weather.drop("windspeed",axis=1,inplace=True)

# %%
df_weather.to_csv(r"C:\Users\ipcs nagpur\Desktop\abc.txt",sep=",")

# %%
df_weather.to_csv(r"C:\Users\ipcs nagpur\Desktop\abc.txt\New_updated_weather.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df_weather.to_csv(r"C:\Users\ipcs nagpur\Desktop\abc.txt\New_updated_weather.csv")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
# ...

# %%
df_weather.to_excel
# Out:
# <bound method NDFrame.to_excel of          day      city  temperature   event
# 0   1/1/2017  new york           32    Rain
# 1   1/2/2017  new york           36   Sunny
# 2   1/3/2017  new york           28    Snow
# 3   1/4/2017  new york           33   Sunny
# 4   1/1/2017    mumbai           90   Sunny
# 5   1/2/2017    mumbai           85     Fog
# 6   1/3/2017    mumbai           87     Fog
# 7   1/4/2017    mumbai           92    Rain
# 8   1/1/2017     paris           45   Sunny
# 9   1/2/2017     paris           50  Cloudy
# 10  1/3/2017     paris           54  Cloudy
# 11  1/4/2017     paris           42  Cloudy>

# %%
df_weather
# Out:
#          day  temperature   event
# 0   1/1/2017         32.0    Rain
# 1   1/4/2017          NaN   Sunny
# 2   1/5/2017         28.0    Snow
# 3   1/6/2017          NaN     NaN
# 4   1/7/2017         32.0    Rain
# 5   1/8/2017          NaN   Sunny
# 6   1/9/2017          NaN     NaN
# 7  1/10/2017         34.0  Cloudy
# 8  1/11/2017         40.0   Sunny

# %%
df_weather.dtypes
# Out:
# day             object
# temperature    float64
# event           object
# dtype: object

# %%
df_weather=pd.read_csv(r"C:\Users\Ashish\Desktop\Velocity\DATA SCI BATCH\Dataset\weather_data.csv",parse_dates=["day"])

# %%
df_weather
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df_weather.dtypes
# Out:
# day            datetime64[ns]
# temperature           float64
# windspeed             float64
# event                  object
# dtype: object

# %%
df_weather.set_index("day",inplace=True)
df_weather
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_weather.isnull().sum()
# Out:
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
df_weather
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ### remove

# %%
df_weather.dropna(how="all")
# all, when all rows value are Nan then remove that row
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_weather.dropna(how="any")
# , when any rows has any  Nan then remove that row
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_weather
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_weather["windspeed"].mean()
# Out:
# 8.4
